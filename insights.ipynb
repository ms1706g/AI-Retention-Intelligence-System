# %%
from google import genai

client = genai.Client(
    api_key="AQ.Ab8RN6JjXeePIuAw58RXhF5aFBI_bFulOTU12-a78o5fZv9kGw"
)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""
    Analyze this churn data and provide
    retention recommendations.
    """
)

print(response.text)
# Out:
# To effectively analyze your churn data and provide specific, actionable retention recommendations, I first need access to the data itself.
#
# However, I can outline the process I would follow and provide **general retention strategies** that are often applicable, along with **tailored recommendations based on *potential* findings** once the data is available.
#
# ---
#
# ### **Part 1: Data Needed for Comprehensive Analysis**
#
# To provide a robust analysis, I would ideally need the following data points for each customer, both churned and active:
#
# 1.  **Customer Profile/Demographics:**
#     *   User ID / Customer ID
#     *   Sign-up Date
#     *   Demographics (Age, Gender, Location - if relevant)
#     *   Company/Industry (for B2B)
#     *   Acquisition Channel (e.g., Organic, Paid Social, Referral)
#
# 2.  **Subscription/Account Details:**
#     *   Subscription Plan (e.g., Basic, Premium, Enterprise)
#     *   Pricing Tier
#     *   Contract Length (e.g., Monthly, Annual)
# ...

# %%
summary = f"""
Total Users: 1000

Churned Users: 350

Top Churn Reasons:

Too Expensive: 120
Not Useful: 90
Technical Issues: 70

Plan Wise Churn:

Basic: 42%
Premium: 26%

Average Subscription:
5.4 Months
"""

# %%
prompt = f"""
You are a Senior Product Strategist.

Analyze the following user retention metrics.

{summary}

Provide:

1. Executive Summary
2. Key Churn Drivers
3. User Behaviour Patterns
4. Retention Strategies
5. Product Recommendations
6. Business Impact

Keep recommendations specific.
"""

# %%
print(top_reasons_df.head())
print(plan_churn_df.head())
print(summary_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(top_reasons_df.head())
#       2 print(plan_churn_df.head())
#       3 print(summary_df.head())
#
# NameError: name 'top_reasons_df' is not defined

# %%
from database import (
    top_reasons_df,
    plan_churn_df,
    summary_df
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from database import (
#       2     top_reasons_df,
#       3     plan_churn_df,
#       4     summary_df
#       5 )
#
# ModuleNotFoundError: No module named 'database'
